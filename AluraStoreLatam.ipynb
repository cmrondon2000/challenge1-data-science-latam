# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
precio_tienda1 = tienda["Precio"].tolist()
ingreso_tienda1 = sum(precio_tienda1)
print(ingreso_tienda1)

precio_tienda2 = tienda2["Precio"].tolist()
ingreso_tienda2 = sum(precio_tienda2)
print(ingreso_tienda2)

precio_tienda3 = tienda3["Precio"].tolist()
ingreso_tienda3 = sum(precio_tienda3)
print(ingreso_tienda3)

precio_tienda4 = tienda4["Precio"].tolist()
ingreso_tienda4 = sum(precio_tienda4)
print(ingreso_tienda4)

nombres_tiendas = ["TIENDA 1", "TIENDA 2", "TIENDA 3", "TIENDA 4"]
ingresos_tiendas = [ingreso_tienda1, ingreso_tienda2, ingreso_tienda3, ingreso_tienda4]

ingresos_totales = [(nombres_tiendas[i], ingresos_tiendas[i]) for i in range(len(nombres_tiendas))]
print(ingresos_totales)

for nombre, ingreso in ingresos_totales:
  if ingreso == max(ingresos_tiendas):
    print(f"La tienda con mayores ingresos es {nombre} con un ingreso de ${ingreso}")

for nombre, ingreso in ingresos_totales:
  if ingreso == min(ingresos_tiendas):
    print(f"La tienda con menores ingresos es {nombre} con un ingreso de ${ingreso}")
# Out:
# 1150880400.0
# 1116343500.0
# 1098019600.0
# 1038375700.0
# [('TIENDA 1', 1150880400.0), ('TIENDA 2', 1116343500.0), ('TIENDA 3', 1098019600.0), ('TIENDA 4', 1038375700.0)]
# La tienda con mayores ingresos es TIENDA 1 con un ingreso de $1150880400.0
# La tienda con menores ingresos es TIENDA 4 con un ingreso de $1038375700.0

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(nombres_tiendas, ingresos_tiendas)
plt.xlabel("Tiendas")
plt.ylabel("Ingresos")
plt.title("Ingresos por tienda")
plt.show()

# %% [markdown]
# # 2. Ventas por categoría

# %%
categoria_tienda1 = tienda["Categoría del Producto"].tolist()
categoria_unica_tienda1 = list(set(categoria_tienda1))
print(categoria_unica_tienda1)

cantidad_categoria_tienda1 = []
for categoria in categoria_unica_tienda1:
  cantidad_categoria_tienda1.append(categoria_tienda1.count(categoria))
print(cantidad_categoria_tienda1)

categorias_totales_tienda1 = [(categoria_unica_tienda1[i], cantidad_categoria_tienda1[i]) for i in range(len(categoria_unica_tienda1))]
print(categorias_totales_tienda1)

for categoria, cantidad in categorias_totales_tienda1:
  if cantidad == max(cantidad_categoria_tienda1):
    print(f"La categoría con más ventas es {categoria} con {cantidad} ventas")


plt.bar(categoria_unica_tienda1, cantidad_categoria_tienda1)
plt.xlabel("Categoria")
plt.ylabel("Cantidad Vendida")
plt.title("Categoria x Ventas Tienda1")
plt.xticks(rotation="vertical")
plt.show()

categoria_tienda2 = tienda2["Categoría del Producto"].tolist()
categoria_unica_tienda2 = list(set(categoria_tienda2))
print(categoria_unica_tienda2)

cantidad_categoria_tienda2 = []
for categoria in categoria_unica_tienda2:
  cantidad_categoria_tienda2.append(categoria_tienda2.count(categoria))
print(cantidad_categoria_tienda2)

categorias_totales_tienda2 = [(categoria_unica_tienda2[i], cantidad_categoria_tienda2[i]) for i in range(len(categoria_unica_tienda2))]
print(categorias_totales_tienda2)

for categoria, cantidad in categorias_totales_tienda2:
  if cantidad == max(cantidad_categoria_tienda2):
    print(f"La categoría con más ventas es {categoria} con {cantidad} ventas")


plt.bar(categoria_unica_tienda2, cantidad_categoria_tienda2)
plt.xlabel("Categoria")
plt.ylabel("Cantidad Vendida")
plt.title("Categoria x Ventas Tienda2")
plt.xticks(rotation="vertical")
plt.show()

categoria_tienda3 = tienda3["Categoría del Producto"].tolist()
categoria_unica_tienda3 = list(set(categoria_tienda3))
print(categoria_unica_tienda3)

cantidad_categoria_tienda3 = []
for categoria in categoria_unica_tienda3:
  cantidad_categoria_tienda3.append(categoria_tienda3.count(categoria))
print(cantidad_categoria_tienda3)

categorias_totales_tienda3 = [(categoria_unica_tienda3[i], cantidad_categoria_tienda3[i]) for i in range(len(categoria_unica_tienda3))]
print(categorias_totales_tienda3)

for categoria, cantidad in categorias_totales_tienda3:
  if cantidad == max(cantidad_categoria_tienda3):
    print(f"La categoría con más ventas es {categoria} con {cantidad} ventas")


plt.bar(categoria_unica_tienda3, cantidad_categoria_tienda3)
plt.xlabel("Categoria")
plt.ylabel("Cantidad Vendida")
plt.title("Categoria x Ventas Tienda3")
plt.xticks(rotation="vertical")
plt.show()

categoria_tienda4 = tienda4["Categoría del Producto"].tolist()
categoria_unica_tienda4 = list(set(categoria_tienda4))
print(categoria_unica_tienda4)

cantidad_categoria_tienda4 = []
for categoria in categoria_unica_tienda4:
  cantidad_categoria_tienda4.append(categoria_tienda4.count(categoria))
print(cantidad_categoria_tienda4)

categorias_totales_tienda4 = [(categoria_unica_tienda4[i], cantidad_categoria_tienda4[i]) for i in range(len(categoria_unica_tienda4))]
print(categorias_totales_tienda4)

for categoria, cantidad in categorias_totales_tienda4:
  if cantidad == max(cantidad_categoria_tienda4):
    print(f"La categoría con más ventas es {categoria} con {cantidad} ventas")


plt.bar(categoria_unica_tienda4, cantidad_categoria_tienda4)
plt.xlabel("Categoria")
plt.ylabel("Cantidad Vendida")
plt.title("Categoria x Ventas Tienda4")
plt.xticks(rotation="vertical")
plt.show()
# Out:
# ['Deportes y diversión', 'Muebles', 'Instrumentos musicales', 'Electrónicos', 'Electrodomésticos', 'Libros', 'Juguetes', 'Artículos para el hogar']
# [284, 465, 182, 448, 312, 173, 324, 171]
# [('Deportes y diversión', 284), ('Muebles', 465), ('Instrumentos musicales', 182), ('Electrónicos', 448), ('Electrodomésticos', 312), ('Libros', 173), ('Juguetes', 324), ('Artículos para el hogar', 171)]
# La categoría con más ventas es Muebles con 465 ventas
# ['Deportes y diversión', 'Instrumentos musicales', 'Muebles', 'Electrónicos', 'Electrodomésticos', 'Libros', 'Juguetes', 'Artículos para el hogar']
# [275, 224, 442, 422, 305, 197, 313, 181]
# [('Deportes y diversión', 275), ('Instrumentos musicales', 224), ('Muebles', 442), ('Electrónicos', 422), ('Electrodomésticos', 305), ('Libros', 197), ('Juguetes', 313), ('Artículos para el hogar', 181)]
# La categoría con más ventas es Muebles con 442 ventas
# ...

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
calificacion_tienda1 = tienda["Calificación"].tolist()
calificacion_media_tienda1 = (sum(calificacion_tienda1) / len(calificacion_tienda1))
print(calificacion_media_tienda1)


calificacion_tienda2 = tienda2["Calificación"].tolist()
calificacion_media_tienda2 = (sum(calificacion_tienda2) / len(calificacion_tienda2))
print(calificacion_media_tienda2)

calificacion_tienda3 = tienda3["Calificación"].tolist()
calificacion_media_tienda3 = (sum(calificacion_tienda3) / len(calificacion_tienda3))
print(calificacion_media_tienda3)

calificacion_tienda4 = tienda4["Calificación"].tolist()
calificacion_media_tienda4 = (sum(calificacion_tienda4) / len(calificacion_tienda4))
print(calificacion_media_tienda4)

nombres_tiendas = ["TIENDA 1", "TIENDA 2", "TIENDA 3", "TIENDA 4"]
calificacion_tiendas = [calificacion_media_tienda1, calificacion_media_tienda2, calificacion_media_tienda3, calificacion_media_tienda4]

calificaciones_totales = [(nombres_tiendas[i], calificacion_tiendas[i]) for i in range(len(nombres_tiendas))]
print(calificaciones_totales)

for nombre, calificacion in calificaciones_totales:
  if calificacion == max(calificacion_tiendas):
    print(f"La tienda con mayor calficación es {nombre} con una calificación de {calificacion:.2f}")

for nombre, calificacion in calificaciones_totales:
  if calificacion == min(calificacion_tiendas):
    print(f"La tienda con menor calificación es {nombre} con una calfiicacion de {calificacion:.2f}")
# Out:
# 3.976685036032217
# 4.037303942348453
# 4.048325561678677
# 3.9957591178965224
# [('TIENDA 1', 3.976685036032217), ('TIENDA 2', 4.037303942348453), ('TIENDA 3', 4.048325561678677), ('TIENDA 4', 3.9957591178965224)]
# La tienda con mayor calficación es TIENDA 3 con una calificación de 4.05
# La tienda con menor calificación es TIENDA 1 con una calfiicacion de 3.98

# %%
plt.plot(nombres_tiendas, calificacion_tiendas)
plt.xlabel("Tiendas")
plt.ylabel("Calificación")
plt.title("Calificación por tienda")
plt.show()

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
producto_tienda1 = tienda["Producto"].tolist()
producto_unica_tienda1 = list(set(producto_tienda1))
print(producto_unica_tienda1)

cantidad_producto_tienda1 = []
for producto in producto_unica_tienda1:
  cantidad_producto_tienda1.append(producto_tienda1.count(producto))
print(cantidad_producto_tienda1)

producto_totales_tienda1 = [(producto_unica_tienda1[i], cantidad_producto_tienda1[i]) for i in range(len(producto_unica_tienda1))]
print(producto_totales_tienda1)

for producto, cantidad in producto_totales_tienda1:
  if cantidad == max(cantidad_producto_tienda1):
    print(f"La categoría con más ventas es {producto} con {cantidad} ventas")

for producto, cantidad in producto_totales_tienda1:
  if cantidad == min(cantidad_producto_tienda1):
    print(f"La categoría con menos ventas es {producto} con {cantidad} ventas")

plt.bar(producto_unica_tienda1, cantidad_producto_tienda1)
plt.xlabel("Producto")
plt.ylabel("Cantidad Vendida")
plt.title("Producto x Ventas Tienda1")
plt.xticks(rotation="vertical")
plt.show()

producto_tienda2 = tienda2["Producto"].tolist()
producto_unica_tienda2 = list(set(producto_tienda2))
print(producto_unica_tienda2)

cantidad_producto_tienda2 = []
for producto in producto_unica_tienda2:
  cantidad_producto_tienda2.append(producto_tienda2.count(producto))
print(cantidad_producto_tienda2)

producto_totales_tienda2 = [(producto_unica_tienda2[i], cantidad_producto_tienda2[i]) for i in range(len(producto_unica_tienda2))]
print(producto_totales_tienda2)

for producto, cantidad in producto_totales_tienda2:
  if cantidad == max(cantidad_producto_tienda2):
    print(f"La categoría con más ventas es {producto} con {cantidad} ventas")

for producto, cantidad in producto_totales_tienda2:
  if cantidad == min(cantidad_producto_tienda2):
    print(f"La categoría con menos ventas es {producto} con {cantidad} ventas")

plt.bar(producto_unica_tienda2, cantidad_producto_tienda2)
plt.xlabel("Producto")
plt.ylabel("Cantidad Vendida")
plt.title("Producto x Ventas Tienda2")
plt.xticks(rotation="vertical")
plt.show()

producto_tienda3 = tienda3["Producto"].tolist()
producto_unica_tienda3 = list(set(producto_tienda3))
print(producto_unica_tienda3)

cantidad_producto_tienda3 = []
for producto in producto_unica_tienda3:
  cantidad_producto_tienda3.append(producto_tienda3.count(producto))
print(cantidad_producto_tienda3)

producto_totales_tienda3 = [(producto_unica_tienda3[i], cantidad_producto_tienda3[i]) for i in range(len(producto_unica_tienda3))]
print(producto_totales_tienda3)

for producto, cantidad in producto_totales_tienda3:
  if cantidad == max(cantidad_producto_tienda3):
    print(f"La categoría con más ventas es {producto} con {cantidad} ventas")

for producto, cantidad in producto_totales_tienda3:
  if cantidad == min(cantidad_producto_tienda3):
    print(f"La categoría con menos ventas es {producto} con {cantidad} ventas")

plt.bar(producto_unica_tienda3, cantidad_producto_tienda3)
plt.xlabel("Producto")
plt.ylabel("Cantidad Vendida")
plt.title("Producto x Ventas Tienda3")
plt.xticks(rotation="vertical")
plt.show()

producto_tienda4 = tienda4["Producto"].tolist()
producto_unica_tienda4 = list(set(producto_tienda4))
print(producto_unica_tienda4)

cantidad_producto_tienda4 = []
for producto in producto_unica_tienda4:
  cantidad_producto_tienda4.append(producto_tienda4.count(producto))
print(cantidad_producto_tienda4)

producto_totales_tienda4 = [(producto_unica_tienda4[i], cantidad_producto_tienda4[i]) for i in range(len(producto_unica_tienda4))]
print(producto_totales_tienda4)

for producto, cantidad in producto_totales_tienda4:
  if cantidad == max(cantidad_producto_tienda4):
    print(f"La categoría con más ventas es {producto} con {cantidad} ventas")

for producto, cantidad in producto_totales_tienda4:
  if cantidad == min(cantidad_producto_tienda4):
    print(f"La categoría con menos ventas es {producto} con {cantidad} ventas")

plt.bar(producto_unica_tienda4, cantidad_producto_tienda4)
plt.xlabel("Producto")
plt.ylabel("Cantidad Vendida")
plt.title("Producto x Ventas Tienda4")
plt.xticks(rotation="vertical")
plt.show()
# Out:
# ['Batería', 'Cama box', 'Kit de bancas', 'Secadora de ropa', 'Refrigerador', 'Set de vasos', 'Ajedrez de madera', 'TV LED UHD 4K', 'Mochila', 'Dashboards con Power BI', 'Vaso térmico', 'Microondas', 'Mesa de comedor', 'Juego de mesa', 'Dinosaurio Rex', 'Iphone 15', 'Balón de voleibol', 'Asistente virtual', 'Pandereta', 'Cubo mágico 8x8', 'Iniciando en programación', 'Mesa de centro', 'Armario', 'Estufa', 'Lavadora de ropa', 'Smart TV', 'Carrito de control remoto', 'Cubertería', 'Smartwatch', 'Tablet ABXY', 'Ciencia de datos con Python', 'Lavavajillas', 'Guitarra eléctrica', 'Bloques de construcción', 'Olla de presión', 'Silla de oficina', 'Bicicleta', 'Muñeca bebé', 'Mesa de noche', 'Balón de baloncesto', 'Auriculares con micrófono', 'Sofá reclinable', 'Celular ABXY', 'Impresora', 'Guitarra acústica', 'Auriculares', 'Modelado predictivo', 'Set de ollas', 'Cama king', 'Sillón', 'Cuerda para saltar']
# ...

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
envio_tienda1 = tienda["Costo de envío"].tolist()
envio_medio_tienda1 = (sum(envio_tienda1) / len(envio_tienda1))
print(envio_medio_tienda1)

envio_tienda2 = tienda2["Costo de envío"].tolist()
envio_medio_tienda2 = (sum(envio_tienda2) / len(envio_tienda2))
print(envio_medio_tienda2)

envio_tienda3 = tienda3["Costo de envío"].tolist()
envio_medio_tienda3 = (sum(envio_tienda3) / len(envio_tienda3))
print(envio_medio_tienda3)

envio_tienda4 = tienda4["Costo de envío"].tolist()
envio_medio_tienda4 = (sum(envio_tienda4) / len(envio_tienda4))
print(envio_medio_tienda4)

nombres_tiendas = ["TIENDA 1", "TIENDA 2", "TIENDA 3", "TIENDA 4"]
envio_tiendas = [envio_medio_tienda1, envio_medio_tienda2, envio_medio_tienda3, envio_medio_tienda4]

envios_totales = [(nombres_tiendas[i], envio_tiendas[i]) for i in range(len(nombres_tiendas))]
print(envios_totales)

for nombre, envio in envios_totales:
  if envio == max(envio_tiendas):
    print(f"La tienda con mayor costo promedio de envios es {nombre} con un valor promedio de $ {envio:.2f}")

for nombre, envio in envios_totales:
  if envio == min(envio_tiendas):
    print(f"La tienda con menor costo promedio de envios es {nombre} con un valor promedio de $ {envio:.2f}")
# Out:
# 26018.60958033065
# 25216.235693090293
# 24805.680373039424
# 23459.457167090754
# [('TIENDA 1', 26018.60958033065), ('TIENDA 2', 25216.235693090293), ('TIENDA 3', 24805.680373039424), ('TIENDA 4', 23459.457167090754)]
# La tienda con mayor costo promedio de envios es TIENDA 1 con un valor promedio de $ 26018.61
# La tienda con menor costo promedio de envios es TIENDA 4 con un valor promedio de $ 23459.46

# %%
plt.pie(envio_tiendas, labels=nombres_tiendas, autopct='%1.1f%%', startangle=90)
plt.title("Valor promedio de los envios por tienda")
plt.show()

# %% [markdown]
# #6. Informe Final
#
# De acuerdo con los resultados obtenidos como se presenta en la siguiente Figura 1 la tienda que genera mayores ingresos es la Tienda 1, mientras que la que menos ingresos genera es la Tienda 4 con una diferencia en ingresos entre la Tienda 1 y la Tienda 4 de $112.504.700.00 millones.
#
# Figura 1
#
# ![image.png](data:image/png;base64,...)
#
# En general en todas las tiendas los productos que mas se venden son los correspondientes a Muebles y Electrodomesticos, en general en casi todas las tiendas los productos mas vendidos corresponden a muebles, por lo cual las tiendas deberian enfocar más la compra y promoción de muebles.
#
# Como se presenta en la Figura 2 La Tienda preferida de los usuarios es la Tienda 3, seguida de la tienda 4 mientras que la que tiene menor aceptación es la Tienda 1, adcional a eso la Tienda 1 es la que en promedio tiene un mayor costo promedio en envios, mientras que la Tienda 4 presenta el menor costo en los envios. Por lo anterior considero que la tienda que debe ser cerrada es la Tienda 2 debido a que es una de la que mas costos de envio genera, sus ingresos estan por debajo de la tienda 1 y los usuarios presentan la segunda peor calificación con respecto a esta tienda.
#
# Figura 2
# ![image.png](data:image/png;base64,...)
